# %%
import pandas as pd

#read the csv dataset
df=pd.read_csv('second_hand_cars.csv')

df
# Out:
#        Company Name Car Name   Variant Fuel Type     Tyre Condition  \
# 0     Maruti Suzuki    Cruze        EX       CNG  Needs Replacement
# 1               Kia   Seltos       RXE    Petrol                New
# 2               Kia   Accord       RXE    Petrol                New
# 3            Nissan   Seltos  Highline    Diesel               Used
# 4         Chevrolet     Kwid  Highline    Petrol               Used
# ...             ...      ...       ...       ...                ...
# 2495         Toyota  Elantra       RXE    Petrol                New
# 2496            Kia    Sunny        LE       CNG  Needs Replacement
# 2497         Nissan    Sunny       RXE    Diesel               Used
# 2498          Honda    Swift        XL       CNG  Needs Replacement
# 2499        Renault     Kwid        GT    Diesel  Needs Replacement
#
#       Make Year Owner Type Registration Number  Mileage   Price  \
# 0          2018     Second         84-436-5584    52798  759107
# ...

# %%
#get first 10 rows
df.head(10)
# Out:
#     Company Name Car Name   Variant Fuel Type     Tyre Condition  Make Year  \
# 0  Maruti Suzuki    Cruze        EX       CNG  Needs Replacement       2018
# 1            Kia   Seltos       RXE    Petrol                New       2020
# 2            Kia   Accord       RXE    Petrol                New       2022
# 3         Nissan   Seltos  Highline    Diesel               Used       2024
# 4      Chevrolet     Kwid  Highline    Petrol               Used       2018
# 5     Volkswagen    Cruze        LE    Petrol                New       2021
# 6  Maruti Suzuki    Camry       NaN       CNG               Used       2017
# 7         Toyota    F-150       NaN       CNG                New       2021
# 8     Volkswagen     Kwid       ZXI    Petrol                New       2022
# 9           Ford    Swift        GT    Petrol               Used       2018
#
#   Owner Type Registration Number  Mileage   Price      Transmission Type  \
# ...

# %%
#get last 5 rows
df.tail(5)
# Out:
#      Company Name Car Name Variant Fuel Type     Tyre Condition  Make Year  \
# 2495       Toyota  Elantra     RXE    Petrol                New       2015
# 2496          Kia    Sunny      LE       CNG  Needs Replacement       2024
# 2497       Nissan    Sunny     RXE    Diesel               Used       2022
# 2498        Honda    Swift      XL       CNG  Needs Replacement       2019
# 2499      Renault     Kwid      GT    Diesel  Needs Replacement       2024
#
#      Owner Type Registration Number  Mileage   Price      Transmission Type  \
# 2495      First         36-450-8953   171112  643581              Automatic
# 2496     Second         77-453-7512    93545  889661                 Manual
# 2497      Third         52-366-2337    47285  327520  Automatic (Tiptronic)
# 2498     Second         10-872-5236    67437  348921                 Manual
# 2499     Second         25-274-7784    88084  955324              Automatic
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company Name              2500 non-null   object
#  1   Car Name                  2500 non-null   object
#  2   Variant                   2238 non-null   object
#  3   Fuel Type                 2500 non-null   object
#  4   Tyre Condition            2500 non-null   object
#  5   Make Year                 2500 non-null   int64
#  6   Owner Type                2500 non-null   object
#  7   Registration Number       2500 non-null   object
#  8   Mileage                   2500 non-null   int64
#  9   Price                     2500 non-null   int64
#  10  Transmission Type         2500 non-null   object
#  11  Body Color                2500 non-null   object
#  12  Service Record            2500 non-null   object
# ...

# %%
df.describe()
# Out:
#          Make Year        Mileage          Price
# count  2500.000000    2500.000000    2500.000000
# mean   2019.521600  104777.792000  608120.897600
# std       2.894146   55544.487467  231056.126713
# min    2015.000000   10010.000000  200176.000000
# 25%    2017.000000   56313.000000  407791.000000
# 50%    2020.000000  104209.500000  612012.500000
# 75%    2022.000000  152149.250000  804567.000000
# max    2024.000000  199755.000000  999826.000000

# %%
#display columns
df.columns
# Out:
# Index(['Company Name', 'Car Name', 'Variant', 'Fuel Type', 'Tyre Condition',
#        'Make Year', 'Owner Type', 'Registration Number', 'Mileage', 'Price',
#        'Transmission Type', 'Body Color', 'Service Record', 'Insurance',
#        'Registration Certificate', 'Accessories'],
#       dtype='object')

# %%
#filter columns
df2=df[['Company Name', 'Car Name', 'Variant','Make Year','Mileage','Price','Body Color','Fuel Type']]

df2.head()
# Out:
#     Company Name Car Name   Variant  Make Year  Mileage   Price Body Color  \
# 0  Maruti Suzuki    Cruze        EX       2018    52798  759107       Grey
# 1            Kia   Seltos       RXE       2020    43412  505071     Maroon
# 2            Kia   Accord       RXE       2022    95219  635322      Black
# 3         Nissan   Seltos  Highline       2024    70370  483152     Maroon
# 4      Chevrolet     Kwid  Highline       2018    85852  712961     Silver
#
#   Fuel Type
# 0       CNG
# 1    Petrol
# 2    Petrol
# 3    Diesel
# 4    Petrol

# %%
#delete columns from the dataframe
df2.drop(['Body Color','Fuel Type'],axis=1,inplace=True)
df2
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_19609/734199841.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['Body Color','Fuel Type'],axis=1,inplace=True)
#        Company Name Car Name   Variant  Make Year  Mileage   Price
# 0     Maruti Suzuki    Cruze        EX       2018    52798  759107
# 1               Kia   Seltos       RXE       2020    43412  505071
# 2               Kia   Accord       RXE       2022    95219  635322
# 3            Nissan   Seltos  Highline       2024    70370  483152
# 4         Chevrolet     Kwid  Highline       2018    85852  712961
# ...             ...      ...       ...        ...      ...     ...
# 2495         Toyota  Elantra       RXE       2015   171112  643581
# 2496            Kia    Sunny        LE       2024    93545  889661
# ...

# %%
print(f"Mean: {df2['Price'].mean()}")
print(f"Median: {df2['Price'].median()}")
print(f"Min: {df2['Price'].min()}")
print(f"Max: {df2['Price'].max()}")
print(f"Std: {df2['Price'].std()}")
# Out:
# Mean: 608120.8976
# Median: 612012.5
# Min: 200176
# Max: 999826
# Std: 231056.1267132967

# %%
#access specific row
df2.loc[4]
# Out:
# Company Name    Chevrolet
# Car Name             Kwid
# Variant          Highline
# Make Year            2018
# Mileage             85852
# Price              712961
# Name: 4, dtype: object

# %%
df2.iloc[4]
# Out:
# Company Name    Chevrolet
# Car Name             Kwid
# Variant          Highline
# Make Year            2018
# Mileage             85852
# Price              712961
# Name: 4, dtype: object

# %%
df3=df2['Make Year']+1000
df3
# Out:
# 0       3018
# 1       3020
# 2       3022
# 3       3024
# 4       3018
#         ...
# 2495    3015
# 2496    3024
# 2497    3022
# 2498    3019
# 2499    3024
# Name: Make Year, Length: 2500, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  2500 non-null   object
#  1   Car Name      2500 non-null   object
#  2   Variant       2238 non-null   object
#  3   Make Year     2500 non-null   int64
#  4   Mileage       2500 non-null   int64
#  5   Price         2500 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 117.3+ KB

# %%
#counting & identifying the missing values
df2.isna().sum()
# Out:
# Company Name      0
# Car Name          0
# Variant         262
# Make Year         0
# Mileage           0
# Price             0
# dtype: int64

# %%
#removing the missing values
df2.dropna(inplace=True)

df2.isna().sum()
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_19609/2545166592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)
# Company Name    0
# Car Name        0
# Variant         0
# Make Year       0
# Mileage         0
# Price           0
# dtype: int64

# %%
# df2.fillna(0,inplace=True) #filling missing values with 0

# df2.isna().sum()

# %%
# average_variant=df2['Variant'].mean()

# df2.fillna(average_variant,inplace=True)

# %%
df2
# Out:
#        Company Name Car Name   Variant  Make Year  Mileage   Price
# 0     Maruti Suzuki    Cruze        EX       2018    52798  759107
# 1               Kia   Seltos       RXE       2020    43412  505071
# 2               Kia   Accord       RXE       2022    95219  635322
# 3            Nissan   Seltos  Highline       2024    70370  483152
# 4         Chevrolet     Kwid  Highline       2018    85852  712961
# ...             ...      ...       ...        ...      ...     ...
# 2495         Toyota  Elantra       RXE       2015   171112  643581
# 2496            Kia    Sunny        LE       2024    93545  889661
# 2497         Nissan    Sunny       RXE       2022    47285  327520
# 2498          Honda    Swift        XL       2019    67437  348921
# 2499        Renault     Kwid        GT       2024    88084  955324
#
# [2238 rows x 6 columns]

# %%
#convert data type
df2['Price']=df2['Price'].astype(float)
df2
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_19609/86172506.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Price']=df2['Price'].astype(float)
#        Company Name Car Name   Variant  Make Year  Mileage     Price
# 0     Maruti Suzuki    Cruze        EX       2018    52798  759107.0
# 1               Kia   Seltos       RXE       2020    43412  505071.0
# 2               Kia   Accord       RXE       2022    95219  635322.0
# 3            Nissan   Seltos  Highline       2024    70370  483152.0
# 4         Chevrolet     Kwid  Highline       2018    85852  712961.0
# ...             ...      ...       ...        ...      ...       ...
# 2495         Toyota  Elantra       RXE       2015   171112  643581.0
# ...

# %%
#find the largest numbers
df2['Price'].nlargest(3)
# Out:
# 2038    999826.0
# 1553    999597.0
# 1921    999319.0
# Name: Price, dtype: float64

# %%
#convert dataframe to series
sr=pd.Series(df2['Car Name'])
sr
# Out:
# 0         Cruze
# 1        Seltos
# 2        Accord
# 3        Seltos
# 4          Kwid
#          ...
# 2495    Elantra
# 2496      Sunny
# 2497      Sunny
# 2498      Swift
# 2499       Kwid
# Name: Car Name, Length: 2238, dtype: object

# %%
sr=sr.map({'Cruze': "Crz", "Seltos": "Slt"})
sr
# Out:
# 0       Crz
# 1       Slt
# 2       NaN
# 3       Slt
# 4       NaN
#        ...
# 2495    NaN
# 2496    NaN
# 2497    NaN
# 2498    NaN
# 2499    NaN
# Name: Car Name, Length: 2238, dtype: object

# %%
df['Transmission Type']
# Out:
# 0                      Manual
# 1                   Automatic
# 2       Automatic (Tiptronic)
# 3       Automatic (Tiptronic)
# 4       Automatic (Tiptronic)
#                 ...
# 2495                Automatic
# 2496                   Manual
# 2497    Automatic (Tiptronic)
# 2498                   Manual
# 2499                Automatic
# Name: Transmission Type, Length: 2500, dtype: object

# %%
print(df['Transmission Type'].unique())

df['Transmission Type'].value_counts()

df['Transmission Type']=df['Transmission Type'].map({'Automatic': 1, 'Manual': 0, 'Automatic (Tiptronic)': 2})

df['Transmission Type']
# Out:
# ['Manual' 'Automatic' 'Automatic (Tiptronic)']
# 0       0
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 2495    1
# 2496    0
# 2497    2
# 2498    0
# 2499    1
# Name: Transmission Type, Length: 2500, dtype: int64

# %%
df2
# Out:
#        Company Name Car Name   Variant  Make Year  Mileage     Price
# 0     Maruti Suzuki    Cruze        EX       2018    52798  759107.0
# 1               Kia   Seltos       RXE       2020    43412  505071.0
# 2               Kia   Accord       RXE       2022    95219  635322.0
# 3            Nissan   Seltos  Highline       2024    70370  483152.0
# 4         Chevrolet     Kwid  Highline       2018    85852  712961.0
# ...             ...      ...       ...        ...      ...       ...
# 2495         Toyota  Elantra       RXE       2015   171112  643581.0
# 2496            Kia    Sunny        LE       2024    93545  889661.0
# 2497         Nissan    Sunny       RXE       2022    47285  327520.0
# 2498          Honda    Swift        XL       2019    67437  348921.0
# 2499        Renault     Kwid        GT       2024    88084  955324.0
#
# [2238 rows x 6 columns]

# %%
# import math
# df2['Price']=df2['Price'].apply(lambda x: math.sqrt(x))
# df2

# %%
total=df2['Price'].sum()
total
# Out:
# 1357568169.0

# %%
df2['Company Name'].unique()
# Out:
# array(['Maruti Suzuki', 'Kia', 'Nissan', 'Chevrolet', 'Volkswagen',
#        'Ford', 'Renault', 'Toyota', 'Hyundai', 'Honda'], dtype=object)

# %%
df2.groupby('Company Name').mean()
# Out:
#                  Make Year        Mileage          Price
# Company Name
# Chevrolet      2019.633484  104309.253394  588834.013575
# Ford           2019.294931  107066.290323  631263.147465
# Honda          2019.497890  103716.675105  626675.088608
# Hyundai        2019.417476  107100.946602  610866.160194
# Kia            2019.715517  104025.176724  603289.327586
# Maruti Suzuki  2019.425926  102536.291667  601387.800926
# Nissan         2019.674797  101695.109756  609652.361789
# Renault        2019.560000  107659.573333  600797.826667
# Toyota         2019.592760  101870.850679  579506.158371
# Volkswagen     2019.589862  105181.585253  612919.732719

# %%
df2.groupby('Company Name').count()
# Out:
#                Car Name  Variant  Make Year  Mileage  Price
# Company Name
# Chevrolet           221      221        221      221    221
# Ford                217      217        217      217    217
# Honda               237      237        237      237    237
# Hyundai             206      206        206      206    206
# Kia                 232      232        232      232    232
# Maruti Suzuki       216      216        216      216    216
# Nissan              246      246        246      246    246
# Renault             225      225        225      225    225
# Toyota              221      221        221      221    221
# Volkswagen          217      217        217      217    217

# %%
x1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})

x2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']})
print(x1)
print(x2)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
x3=pd.concat([x1,x2],axis=0,ignore_index=True)
# x3=pd.concat([x1,x2],axis=0)
# x3.reset_index(inplace=True,drop=True)
x3
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df2
# Out:
#        Company Name Car Name   Variant  Make Year  Mileage     Price
# 0     Maruti Suzuki    Cruze        EX       2018    52798  759107.0
# 1               Kia   Seltos       RXE       2020    43412  505071.0
# 2               Kia   Accord       RXE       2022    95219  635322.0
# 3            Nissan   Seltos  Highline       2024    70370  483152.0
# 4         Chevrolet     Kwid  Highline       2018    85852  712961.0
# ...             ...      ...       ...        ...      ...       ...
# 2495         Toyota  Elantra       RXE       2015   171112  643581.0
# 2496            Kia    Sunny        LE       2024    93545  889661.0
# 2497         Nissan    Sunny       RXE       2022    47285  327520.0
# 2498          Honda    Swift        XL       2019    67437  348921.0
# 2499        Renault     Kwid        GT       2024    88084  955324.0
#
# [2238 rows x 6 columns]

# %%
df2.sort_values('Price',ascending=True,inplace=True)
df2
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_19609/635768948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.sort_values('Price',ascending=True,inplace=True)
#        Company Name Car Name   Variant  Make Year  Mileage     Price
# 451   Maruti Suzuki     Polo        SL       2023   139257  200176.0
# 1209         Toyota     Polo        LE       2016   190441  201314.0
# 408         Hyundai    Camry        SE       2018   181491  201941.0
# 1901     Volkswagen    Camry  Highline       2020   191835  202627.0
# 403          Toyota    F-150  Highline       2019   135885  202878.0
# ...             ...      ...       ...        ...      ...       ...
# 2455     Volkswagen  Elantra        SL       2019   164231  998236.0
# ...

# %%
df2.isna().sum()
# Out:
# Company Name    0
# Car Name        0
# Variant         0
# Make Year       0
# Mileage         0
# Price           0
# dtype: int64

# %%
dates = pd.to_datetime(['2024-07-04', '2024-08-04', '2024-09-04'])
print(dates)
# Out:
# DatetimeIndex(['2024-07-04', '2024-08-04', '2024-09-04'], dtype='datetime64[ns]', freq=None)

# %%
index = pd.date_range('1/1/2023', periods=5, freq='D')
series = pd.Series(range(5), index=index)
print("Original Series:")
print(series)
# Out:
# Original Series:
# 2023-01-01    0
# 2023-01-02    1
# 2023-01-03    2
# 2023-01-04    3
# 2023-01-05    4
# Freq: D, dtype: int64

# %%
print("\nResampled Series:")
print(series.resample('2D').sum())
# Out:
# Resampled Series:
# 2023-01-01    1
# 2023-01-03    5
# 2023-01-05    4
# Freq: 2D, dtype: int64

# %%
df2.head()

df3=df2[df2['Make Year']>2015]
df3['Make Year'].unique()
df3.head()
# Out:
#        Company Name Car Name   Variant  Make Year  Mileage     Price
# 451   Maruti Suzuki     Polo        SL       2023   139257  200176.0
# 1209         Toyota     Polo        LE       2016   190441  201314.0
# 408         Hyundai    Camry        SE       2018   181491  201941.0
# 1901     Volkswagen    Camry  Highline       2020   191835  202627.0
# 403          Toyota    F-150  Highline       2019   135885  202878.0

# %%
# df4=df2[ df2['Price']<300000 and df2['Make Year']>2015 ]
df4=df2[df2['Price']<300000] 

df4['Price'].max()
# Out:
# 299415.0

# %%
#custom query
df5=df2.query('Price<300000 and `Make Year`>2015 and `Company Name`=="Toyota"')
df5.sort_values('Make Year',ascending=False,inplace=True)
df5
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_19609/2638614075.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.sort_values('Make Year',ascending=False,inplace=True)
#      Company Name Car Name   Variant  Make Year  Mileage     Price
# 266        Toyota  Elantra        SE       2024   167416  287394.0
# 1977       Toyota    Sunny  Highline       2024    77199  280166.0
# 1365       Toyota    Swift       ZXI       2024    23969  231659.0
# 1165       Toyota   Seltos        EX       2024   147538  238337.0
# 636        Toyota    Camry        SL       2022    82895  251641.0
# 688        Toyota    Sunny       ZXI       2022   168786  220581.0
# 1887       Toyota    Cruze        GT       2022    16551  223386.0
# ...

# %%
df6=df2.groupby('Company Name').mean()
df6
# Out:
#                  Make Year        Mileage          Price
# Company Name
# Chevrolet      2019.633484  104309.253394  588834.013575
# Ford           2019.294931  107066.290323  631263.147465
# Honda          2019.497890  103716.675105  626675.088608
# Hyundai        2019.417476  107100.946602  610866.160194
# Kia            2019.715517  104025.176724  603289.327586
# Maruti Suzuki  2019.425926  102536.291667  601387.800926
# Nissan         2019.674797  101695.109756  609652.361789
# Renault        2019.560000  107659.573333  600797.826667
# Toyota         2019.592760  101870.850679  579506.158371
# Volkswagen     2019.589862  105181.585253  612919.732719

# %%
df6['Price'].plot(kind='line')
# Out:
# <Axes: xlabel='Company Name'>

# %%
df7=df4.groupby('Company Name').count()
df7.plot(kind='pie',y='Car Name',legend=False)
# Out:
# <Axes: ylabel='Car Name'>

# %%
df2['Price'].plot(kind='box')
# Out:
# <Axes: >

# %%
df6['Price'].plot(kind='line',title='Average Price of Cars by Company Name',xlabel='Company Name',ylabel='Price')
# Out:
# <Axes: title={'center': 'Average Price of Cars by Company Name'}, xlabel='Company Name', ylabel='Price'>
